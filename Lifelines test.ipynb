# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from lifelines.datasets import load_dd

data = load_dd()

# %%
print(len(data[data['observed'] == 1]))
print(len(data[data['observed'] == 0]))
# Out:
# 1468
# 340

# %%
data
# Out:
#                  ctryname  cowcode2  politycode   un_region_name  \
# 0             Afghanistan       700       700.0    Southern Asia
# 1             Afghanistan       700       700.0    Southern Asia
# 2             Afghanistan       700       700.0    Southern Asia
# 3             Afghanistan       700       700.0    Southern Asia
# 4             Afghanistan       700       700.0    Southern Asia
# 5             Afghanistan       700       700.0    Southern Asia
# 6             Afghanistan       700       700.0    Southern Asia
# 7             Afghanistan       700       700.0    Southern Asia
# 8             Afghanistan       700       700.0    Southern Asia
# 9             Afghanistan       700       700.0    Southern Asia
# 10                Albania       339       339.0  Southern Europe
# 11                Albania       339       339.0  Southern Europe
# 12                Albania       339       339.0  Southern Europe
# ...

# %%
from lifelines.datasets import load_regression_dataset
df = load_regression_dataset()
df
# Out:
#          var1      var2      var3          T  E
# 0    0.595170  1.143472  1.571079  14.785479  1
# 1    0.209325  0.184677  0.356980   7.336734  1
# 2    0.693919  0.071893  0.557960   5.271527  1
# 3    0.443804  1.364646  0.374221  11.684168  1
# 4    1.613324  0.125566  1.921325   7.637764  1
# 5    0.065636  0.098375  0.237896  12.678268  1
# 6    0.386294  1.663092  0.790314   6.601660  1
# 7    0.946688  1.345394  3.209113  11.369137  1
# 8    0.113740  0.409860  0.064934  14.680468  1
# 9    0.777793  0.334990  0.411055  10.585059  1
# 10   0.044280  0.305158  0.176480  19.370937  1
# 11   1.035450  3.304733  0.997323   5.558556  1
# 12   0.229195  0.581355  0.484794  11.292129  1
# 13   0.055970  2.674135  0.355279   9.919992  0
# 14   1.236583  1.796598  0.179952   9.884988  1
# 15   1.162835  0.464759  2.028854   6.265627  1
# 16   0.149436  2.949291  0.277801  13.812381  1
# 17   0.399475  0.822413  0.673405   6.433643  1
# 18   0.762121  0.050407  1.285163   6.979698  1
# ...

# %%
from lifelines.datasets import load_waltons
df = load_waltons() 
T = df['T']
E = df['E']
from lifelines import KaplanMeierFitter
kmf = KaplanMeierFitter()
kmf.fit(T, event_observed=E)  # or, more succiently, kmf.fit(T, E)
# Out:
# <lifelines.KaplanMeierFitter: fitted with 163 observations, 7 censored>

# %%
df
# Out:
#         T  E    group
# 0     6.0  1  miR-137
# 1    13.0  1  miR-137
# 2    13.0  1  miR-137
# 3    13.0  1  miR-137
# 4    19.0  1  miR-137
# 5    19.0  1  miR-137
# 6    19.0  1  miR-137
# 7    26.0  1  miR-137
# 8    26.0  1  miR-137
# 9    26.0  1  miR-137
# 10   26.0  1  miR-137
# 11   26.0  1  miR-137
# 12   33.0  1  miR-137
# 13   33.0  1  miR-137
# 14   47.0  1  miR-137
# 15   62.0  1  miR-137
# 16   62.0  1  miR-137
# 17    9.0  1  miR-137
# 18    9.0  1  miR-137
# 19    9.0  1  miR-137
# 20   15.0  1  miR-137
# 21   15.0  1  miR-137
# 22   22.0  1  miR-137
# 23   22.0  1  miR-137
# 24   22.0  1  miR-137
# 25   22.0  1  miR-137
# 26   29.0  1  miR-137
# 27   29.0  1  miR-137
# 28   29.0  1  miR-137
# 29   29.0  1  miR-137
# ..    ... ..      ...
# 133  69.0  1  control
# 134  38.0  1  control
# 135  38.0  1  control
# 136  45.0  1  control
# 137  45.0  1  control
# 138  45.0  1  control
# 139  45.0  1  control
# 140  45.0  1  control
# 141  45.0  1  control
# ...

# %% [markdown]
# #### Censorship
# Individuals in a population who have not been subject to the death event are labeled as right-censored, i.e., **we did not (or can not) view the rest of their life history due to some external circumstances.** All the information we have on these individuals are their current lifetime durations (which is naturally less than their actual lifetimes).

# %%
from lifelines.plotting import plot_lifetimes
from numpy.random import uniform, exponential

N = 25
current_time = 10
actual_lifetimes = np.array([[exponential(12), exponential(2)][uniform() < 0.5] for i in range(N)])
observed_lifetimes = np.minimum(actual_lifetimes, current_time)
observed = actual_lifetimes < current_time

plt.xlim(0, 25)
plt.vlines(10, 0, 30, lw=2, linestyles='--')
plt.xlabel("time")
plt.title("Births and deaths of our population, at $t=10$")
plot_lifetimes(observed_lifetimes, event_observed=observed)
print("Observed lifetimes at time %d:\n" % (current_time), observed_lifetimes)
# Out:
# Observed lifetimes at time 10:
#  [ 10.          10.          10.          10.           0.91258813
#    1.75833409  10.           0.02464938   0.34378339   0.97893956  10.
#    5.51708103   2.95914445   0.23749707   0.53624436   5.44569019  10.
#    2.34100035   7.69613146   1.18373702   2.55520282   0.99455209  10.
#    3.71267831   0.87604616]

# %%
kmf.survival_function_
kmf.median_
kmf.plot()

# %%
kmf.survival_function_
# Out:
#           KM_estimate
# timeline
# 0.0          1.000000
# 6.0          0.993865
# 7.0          0.987730
# 9.0          0.969210
# 13.0         0.950690
# 15.0         0.938344
# 17.0         0.932170
# 19.0         0.913650
# 22.0         0.888957
# 26.0         0.858090
# 29.0         0.827224
# 32.0         0.821051
# 33.0         0.802531
# 36.0         0.790184
# 38.0         0.777837
# 41.0         0.734624
# 43.0         0.728451
# 45.0         0.672891
# 47.0         0.666661
# 48.0         0.616817
# 51.0         0.598125
# 53.0         0.554512
# 54.0         0.542051
# 56.0         0.429903
# 58.0         0.404981
# 60.0         0.311524
# 61.0         0.254305
# 62.0         0.240921
# 63.0         0.180690
# 66.0         0.160614
# 68.0         0.100384
# 69.0         0.014341
# 75.0         0.000000

# %% [markdown]
# Kaplan–Meier estimator, also known as the product limit estimator, is a non-parametric statistic used to estimate the survival function from lifetime data. In medical research, it is often used to measure the fraction of patients living for a certain amount of time after treatment. In other fields, Kaplan–Meier estimators may be used to measure the length of time people remain unemployed after a job loss, the time-to-failure of machine parts, or how long fleshy fruits remain on plants before they are removed by frugivores. The estimator is named after Edward L. Kaplan and Paul Meier, who each submitted similar manuscripts to the Journal of the American Statistical Association. The journal editor, John Tukey, convinced them to combine their work into one paper, which has been cited about 50,000 times since its publication.
#
# The estimator is given by:
#
# {{\displaystyle {\widehat {S}}(t)=\prod \limits _{i:\ t_{i}\leq t}\left(1-{\frac {d_{i}}{n_{i}}}\right),} {\displaystyle {\widehat {S}}(t)=\prod \limits _{i:\ t_{i}\leq t}\left(1-{\frac {d_{i}}{n_{i}}}\right),}
# with {\displaystyle t_{i}} t_{i} a time when at least one event happened, di the number of events (i.e., deaths) that happened at time {\displaystyle t_{i}} t_{i} and {\displaystyle n_{i}} {\displaystyle n_{i}} the individuals known to survive (have not yet had an event or been censored) at time {\displaystyle t_{i}} t_{i}.
